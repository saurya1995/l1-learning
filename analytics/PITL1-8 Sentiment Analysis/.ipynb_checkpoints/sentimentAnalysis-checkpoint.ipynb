# %%
from textblob import TextBlob
import nltk
import json
from nltk.tokenize import word_tokenize, sent_tokenize
import itertools
import matplotlib.pyplot as plt
from nltk.sentiment import SentimentIntensityAnalyzer
import os
import glob
import re
import math

# %% [markdown]
# ## initialize user_data dictionary
# {username:[name, {maxscore:  , message:  },  {minscore: , message: },  [all_scores]]

# %%
def get_user_data():
    # open users file and get user_id and user_name
    users_data = {}
    with open('../data/slack/users.json') as f:
        users = json.load(f)
    for i in range(len(users)):
        user_id = users[i]['id']
        user_name = users[i]['name']
        all_scores = []
        scores = []
        max_score_dict = {}
        max_score_dict['maxscorevalue'] = -2
        max_score_dict['message'] = ''
        min_score_dict = {}
        min_score_dict['minscorevalue']  = 2
        min_score_dict['message'] = ''
        scores.append(user_name)
        scores.append(max_score_dict)
        scores.append(min_score_dict)
        scores.append(all_scores)
        if user_name not in users_data:
            users_data[user_id] = scores
#     print(users_data)
    return users_data

# %% [markdown]
# ## Loop all chat histories data in files

# %%
def loop_all_data_in_files():
#   get all users from get_user_data() function
    users_data = get_user_data()
    
#   get immediate subdirectories under data/slack
    slack_dir = '../data/slack'
    list_subfolders_with_paths = [f.path for f in os.scandir(slack_dir) if f.is_dir()]
    
#   save all files path into an array
    list_files_with_paths = []
    for subfolder in list_subfolders_with_paths:
        for file in os.listdir(subfolder):
            list_files_with_paths.append(os.path.join(subfolder, file))
            
#   loop files path array
    for path in list_files_with_paths: 
#       call get_main_data_from_chat_history
        get_main_data_from_chat_history(path, users_data)
    return users_data

# %%
def clean_tag(sentence):
    tag = re.compile('<.*?>')
    sentence_without_tag = re.sub(tag, '', sentence)
    return sentence_without_tag

# %% [markdown]
# ## Calculate each sentence in a text. Return currentMaxScore and its message

# %%
def calculate_sentence_score_by_model(sentences):
#   separate_sentances, separate_words = get_main_data_from_chat_history()
    nltk.download('vader_lexicon')
    scores = []
    min_score = 2
    min_score_message = ''
    max_score = -2
    max_score_message = ''
    for i in range(len(sentences)):
        sentence = sentences[i]
        sentence = clean_tag(sentence)
        sentence_score = SentimentIntensityAnalyzer().polarity_scores(sentence)["compound"]
        if sentence_score < min_score:
            min_score = sentence_score
            min_score_message = sentence
        if sentence_score > max_score:
            max_score = sentence_score
            max_score_message = sentence
        scores.append(sentence_score)
#         print(max_score,min_score)
    return [[max_score, max_score_message], [min_score, min_score_message], scores]

# %% [markdown]
# ## Get messages from each file, split messages into sentences and calculate it.

# %%
def get_main_data_from_chat_history(path, users_data):
#   open file with path
    with open(path) as f:
        data = json.load(f)
#   download nltk to tokenize the messages into sentences   
    nltk.download('punkt')
    for i in range(len(data)):
        if 'user' in data[i]:
            text = data[i]['text']
            user = data[i]['user']
            scores = calculate_sentence_score_by_model(sent_tokenize(text))
            max_score_in_dict = users_data[user][1]['maxscorevalue']
            max_score_in_last_calcu = scores[0][0]
            min_score_in_dict = users_data[user][2]['minscorevalue']
            min_score_in_last_calcu = scores[1][0]
            if max_score_in_last_calcu > max_score_in_dict:
#                 print("max shoud change")
                users_data[user][1]['message'] = scores[0][1]
                users_data[user][1]['maxscorevalue'] = max_score_in_last_calcu
            if min_score_in_last_calcu < min_score_in_dict:
                users_data[user][2]['message'] = scores[1][1]
                users_data[user][2]['minscorevalue'] = min_score_in_last_calcu
            users_data[user][3].extend(scores[2])
#     print(users_data)
    return

# %% [markdown]
# ## Calculate avg, median score and return result in required format
# now : {username:[name, {maxscore:  , message:  },  {minscore: , message: },  [all_scores]]
# required:
# {"data":
#     [
#        {"name":
#         "avgscore":
#         "medianscore":
#         tmaxscore: {maxscorevalue:  , message. }
#         minScore: {minscorevalue:  , message  }
#        },
#
#        {},
#     ]
# }

# %%
import numpy

# %%
def calculate_avg_var_median(all_scores):
#     all_scores = users_data[3]
    avg_score = numpy.mean(all_scores)
    median_score = numpy.median(all_scores)
    variance_score = numpy.var(all_scores)
    if math.isnan(avg_score):
        avg_score = -2
    if math.isnan(median_score):
        median_score = -2
    if math.isnan(variance_score):
        variance_score = -2
    return [avg_score, median_score, variance_score]

# %%
def modify_result_format():
    users_data = loop_all_data_in_files()
    result_users_data_list = []
    result_users_data = {}
    for user_id in users_data:
        scores = calculate_avg_var_median(users_data[user_id][3])
        avg_score = scores[0]
        median_score = scores[1]
        variance_score = scores[2]
        user_name = users_data[user_id][0]
        maxscore_dict = users_data[user_id][1]
        minscore_dict = users_data[user_id][2]
        user = {}
        user['name'] = user_name
        user['avgscore'] = avg_score
        user['variancescore'] = variance_score
        user['medianscore'] = median_score
        user['maxscore'] = maxscore_dict
        user['minscore'] = minscore_dict
        result_users_data_list.append(user)
    result_users_data['data'] = result_users_data_list
#     print(result_users_data)
    return result_users_data

# %% [markdown]
# ## Change result format to json

# %%
def get_user_data_in_json():
    users_data = modify_result_format()
    data_in_json = json.dumps(users_data, indent=4)
    print(data_in_json)
    return 
get_user_data_in_json()
# Out:
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# ...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# {
#     "data": [
#         {
#             "name": "simon.speth",
#             "avgscore": 0.0,
#             "variancescore": 0.0,
#             "medianscore": 0.0,
#             "maxscore": {
#                 "maxscorevalue": 0.0,
#                 "message": " has joined the channel"
#             },
#             "minscore": {
#                 "minscorevalue": 0.0,
#                 "message": " has joined the channel"
#             }
#         },
#         {
#             "name": "guyiyu",
#             "avgscore": 0.033025000000000006,
#             "variancescore": 0.072668091875,
#             "medianscore": 0.0,
#             "maxscore": {
#                 "maxscorevalue": 0.6486,
#                 "message": "Hi nice to meet you all :wave::skin-tone-2:\nWould like to ask, when you guys prefer an icebreaker video chat?"
#             },
#             "minscore": {
#                 "minscorevalue": -0.9027,
#                 "message": "2021/04/25 13:18:56 handlers.go:373: Get \"\": dial tcp 172.21.0.3:5430: connect: connection\n refused\n2021/04/25 13:40:08 handlers.go:373: Get \"\": dial tcp 172.21.0.3:5430: connect: connection refused\n2021/04/25 13:40:08 handlers.go:373: Get \"\": dial tcp 172.21.0.3:5430: connect: connection refused\n2021/04/25 13:41:20 handlers.go:373: Get \"\": dial tcp 172.21.0.3:5430: connect: connection refused\n2021/04/25 13:41:20 handlers.go:373: Get \"\": dial tcp 172.21.0.3:5430: connect: connection refused\n2021/04/25 13:41:59 handlers.go:373: Get \"\": dial tcp 172.21.0.3:5430: connect: connection\n refused```\nHi, have anyone met this problem before?"
#             }
#         },
#         {
#             "name": "00000000014a3888",
#             "avgscore": 0.12769347826086958,
#             "variancescore": 0.06527201408790169,
#             "medianscore": 0.0,
#             "maxscore": {
#                 "maxscorevalue": 0.6597,
#                 "message": "For login thing in the system, I tried to manually create a user (direct http request) to revelori and create .env file for clotilde to direct to Api address and it surprisingly works."
#             },
#             "minscore": {
#                 "minscorevalue": -0.3612,
#                 "message": "I am still jet lagging hard from flight."
#             }
#         },
#         {
#             "name": "nikanmog",
#             "avgscore": 0.18451891891891892,
#             "variancescore": 0.07693795558802045,
#             "medianscore": 0.0,
#             "maxscore": {
#                 "maxscorevalue": 0.7684,
#                 "message": "Our meeting on Friday will be moved to another date (TBD) but please give a status update on your progress by *Friday 9PM."
#             },
#             "minscore": {
#                 "minscorevalue": -0.2755,
#                 "message": "What I meant to say is that we did not agree on a time yet and if 9:30 won't work 9 won't work either"
#             }
#         },
#         {
#             "name": "fehrenstorfer",
#             "avgscore": 0.1326153846153846,
#             "variancescore": 0.045793635147929015,
#             "medianscore": 0.0,
#             "maxscore": {
#                 "maxscorevalue": 0.7717,
#                 "message": "Looks like today at 4 pm is the best time:grin:"
#             },
#             "minscore": {
#                 "minscorevalue": 0.0,
#                 "message": " has joined the channel"
#             }
#         },
#         {
#             "name": "ge34cal",
#             "avgscore": 0.1415212121212121,
#             "variancescore": 0.07300064955004593,
#             "medianscore": 0.0,
#             "maxscore": {
#                 "maxscorevalue": 0.8074,
#                 "message": "In case it turns out to be a bigger task and it\u2019d be good to have some help,  also volunteered to help."
#             },
#             "minscore": {
#                 "minscorevalue": -0.4215,
#                 "message": "Hey peeps , I\u2019ve been the past 10 hours in an emergency room and unfortunately won\u2019t be able to join our meeting today."
#             }
#         },
#         {
#             "name": "saurypande",
#             "avgscore": 0.01366,
#             "variancescore": 0.0035453164000000007,
#             "medianscore": 0.0,
#             "maxscore": {
#                 "maxscorevalue": 0.2732,
#                 "message": "It's not working maybe we need to create a new link."
#             },
#             "minscore": {
#                 "minscorevalue": 0.0,
#                 "message": " has joined the channel"
#             }
#         },
#         {
#             "name": "ga65hif",
#             "avgscore": 0.03675384615384615,
#             "variancescore": 0.04841799479289942,
#             "medianscore": 0.0,
#             "maxscore": {
#                 "maxscorevalue": 0.5209,
#                 "message": "I would suggest though ensuring the icebreaker meeting is announced 1 day before, so everyone has a chance to see the time."
#             },
#             "minscore": {
#                 "minscorevalue": -0.4939,
#                 "message": "Im sorry :("
#             }
#         },
#         {
#             "name": "valentin",
#             "avgscore": 0.22825531914893615,
#             "variancescore": 0.09986842374830239,
#             "medianscore": 0.0258,
#             "maxscore": {
#                 "maxscorevalue": 0.8613,
#                 "message": "\u2022 Use Cases \u2013 informational\n\u2022 Stand-up notes from today\n, if you would be so kind to update your branch according to the best practices?"
#             },
#             "minscore": {
#                 "minscorevalue": -0.4199,
#                 "message": "No, you will need to add test users to Revolori yourself, sorry!"
#             }
#         },
#         {
#             "name": "basakakan",
#             "avgscore": 0.14552,
#             "variancescore": 0.06880860204444447,
#             "medianscore": 0.0,
#             "maxscore": {
#                 "maxscorevalue": 0.6792,
#                 "message": "Yeah nice job !!"
#             },
#             "minscore": {
#                 "minscorevalue": -0.4019,
#                 "message": "My error message has changed somehow."
#             }
#         },
#         {
#             "name": "manuelmanso",
#             "avgscore": 0.24681250000000002,
#             "variancescore": 0.10179885109375002,
#             "medianscore": 0.0,
#             "maxscore": {
#                 "maxscorevalue": 0.6908,
#                 "message": "Ah nice, thanks"
#             },
#             "minscore": {
#                 "minscorevalue": 0.0,
#                 "message": " has joined the channel"
#             }
#         },
#         {
#             "name": "00000000014974b7",
#             "avgscore": 0.0038074074074074074,
#             "variancescore": 0.05782747772290809,
#             "medianscore": 0.0,
#             "maxscore": {
#                 "maxscorevalue": 0.6124,
#                 "message": "Yes, please."
#             },
#             "minscore": {
#                 "minscorevalue": -0.631,
#                 "message": "The other option is to  make the meeting from 9:30-10:30, but  is going to be sleep deprived :sweat_smile:"
#             }
#         },
#         {
#             "name": "alexandereichler",
#             "avgscore": 0.08113529411764707,
#             "variancescore": 0.03595700110726643,
#             "medianscore": 0.0,
#             "maxscore": {
#                 "maxscorevalue": 0.7579,
#                 "message": "TEAM J: perfect :smile: nice guys"
#             },
#             "minscore": {
#                 "minscorevalue": -0.1969,
#                 "message": "No problem, I hope it's nothing too serious"
#             }
#         },
#         {
#             "name": "zhiyiniu",
#             "avgscore": 0.08981509433962265,
#             "variancescore": 0.04718160203631186,
#             "medianscore": 0.0,
#             "maxscore": {
#                 "maxscorevalue": 0.7034,
#                 "message": "OK, if 9:00 is better for all,  let's just start at 9:00."
#             },
#             "minscore": {
#                 "minscorevalue": -0.4333,
#                 "message": "But I am not sure if some features are limited to me or not."
#             }
#         },
#         {
#             "name": "hohmannr",
#             "avgscore": 0.052871739130434775,
#             "variancescore": 0.0477333072448015,
#             "medianscore": 0.0,
#             "maxscore": {
#                 "maxscorevalue": 0.6597,
#                 "message": "But probably a good idea would be to have a docker-compose file ready for which combines all the three technologies, so we can run the system with a single command."
#             },
#             "minscore": {
#                 "minscorevalue": -0.6369,
#                 "message": "I am an idiot, I always forget that the JavaScript is running client side."
#             }
#         },
#         {
#             "name": "ge25zek",
#             "avgscore": 0.06440625,
#             "variancescore": 0.038995958085937504,
#             "medianscore": 0.0,
#             "maxscore": {
#                 "maxscorevalue": 0.6114,
#                 "message": "Perfect, so see you all at 4!"
#             },
#             "minscore": {
#                 "minscorevalue": -0.2044,
#                 "message": "I assume not much more important was said?"
#             }
#         },
#         {
#             "name": "outlook_calendar",
#             "avgscore": -2,
#             "variancescore": -2,
#             "medianscore": -2,
#             "maxscore": {
#                 "maxscorevalue": -2,
#                 "message": ""
#             },
#             "minscore": {
#                 "minscorevalue": 2,
#                 "message": ""
#             }
#         },
#         {
#             "name": "maxz",
#             "avgscore": 0.19490909090909092,
#             "variancescore": 0.0688479244628099,
#             "medianscore": 0.0,
#             "maxscore": {
#                 "maxscorevalue": 0.6486,
#                 "message": "I also looked at the api's of the tools, since i wanted to know how our potential data will look like, maybe you will find it helpful "
#             },
#             "minscore": {
#                 "minscorevalue": -0.1531,
#                 "message": "There was no timeframe given, but anyway :smile:"
#             }
#         },
#         {
#             "name": "ga27koc",
#             "avgscore": 0.09441750000000002,
#             "variancescore": 0.057035397943749996,
#             "medianscore": 0.0,
#             "maxscore": {
#                 "maxscorevalue": 0.836,
#                 "message": " I forgot to mention: This might be a good opportunity to create a first branch / merge request as well"
#             },
#             "minscore": {
#                 "minscorevalue": -0.4767,
#                 "message": "Maybe something went wrong in the initial step"
#             }
#         },
#         {
#             "name": "simplepoll",
#             "avgscore": 0.0,
#             "variancescore": 0.0,
#             "medianscore": 0.0,
#             "maxscore": {
#                 "maxscorevalue": 0.0,
#                 "message": " has joined the channel"
#             },
#             "minscore": {
#                 "minscorevalue": 0.0,
#                 "message": " has joined the channel"
#             }
#         },
#         {
#             "name": "zoom",
#             "avgscore": -2,
#             "variancescore": -2,
#             "medianscore": -2,
#             "maxscore": {
#                 "maxscorevalue": -2,
#                 "message": ""
#             },
#             "minscore": {
#                 "minscorevalue": 2,
#                 "message": ""
#             }
#         }
#     ]
# }
# [nltk_data] Downloading package punkt to /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zhiyiniu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# /Users/zhiyiniu/opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/zhiyiniu/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/zhiyiniu/opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/zhiyiniu/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:194: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(
# /Users/zhiyiniu/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
